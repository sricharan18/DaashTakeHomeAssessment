# %%
import pandas as pd

# %%
df = pd.read_csv('Lowes_data.csv', na_values=['NA'])

# %%
df
# Out:
#                      Brand      ModelId  Price  \
# 0    National Tree Company  HC7-104-24W  49.98
# 1            Worth Imports         7370  29.98
# 2                Glitzhome   2019500005  35.19
# 3           Nearly Natural         4648  87.45
# 4                Glitzhome   2005500067  40.46
# ..                     ...          ...    ...
# 141          Worth Imports        12019  50.48
# 142             Northlight     34316662  49.98
# 143             Northlight     35182618  74.98
# 144         Nearly Natural        W1255  64.98
# 145              Glitzhome   2006300035  63.98
#
#                                             ProductURL  \
# 0    https://www.lowes.com/pd/National-Tree-Company...
# 1    https://www.lowes.com/pd/Worth-Imports-18-in-F...
# 2    https://www.lowes.com/pd/Glitzhome-24-in-D-Fal...
# 3    https://www.lowes.com/pd/Nearly-Natural-28-in-...
# 4    https://www.lowes.com/pd/Glitzhome-18-5-in-D-F...
# ..                                                 ...
# ...

# %% [markdown]
# # No.of Wreaths per Brand

# %%
pd.DataFrame(df['Brand'].value_counts())
# Out:
#                        count
# Brand
# Nearly Natural            42
# Northlight                35
# Worth Imports             32
# National Tree Company     14
# Sullivans                  8
# Glitzhome                  5
# Gerson International       2
# Puleo International        2
# Haute Decor                2
# Fraser Hill Farm           1

# %% [markdown]
# # Price range for wreaths

# %%
df.groupby("Brand").agg({'Price': ['max', 'min']}).reset_index()
# Out:
#                    Brand   Price
#                              max     min
# 0       Fraser Hill Farm   40.16   40.16
# 1   Gerson International   53.98   45.00
# 2              Glitzhome   63.98   30.48
# 3            Haute Decor   69.99   69.99
# 4  National Tree Company   95.64   37.35
# 5         Nearly Natural   90.77   31.95
# 6             Northlight   95.01   23.98
# 7    Puleo International  135.00  135.00
# 8              Sullivans   45.00   26.98
# 9          Worth Imports   94.98   18.97

# %% [markdown]
# # Histogram of product prices

# %%
import matplotlib.pyplot as plt

plt.hist(df['Price'], bins=20) 
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Product Prices')
plt.show()

# %% [markdown]
# # Most frequently occurring features and keywords from the product descriptions

# %%
from wordcloud import WordCloud

all_descriptions = " ".join(df['Description'].dropna())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_descriptions)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Feature Popularity Analysis - Word Cloud', fontsize=16)
plt.show()
