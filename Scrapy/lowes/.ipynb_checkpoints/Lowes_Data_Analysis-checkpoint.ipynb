# %%
import pandas as pd

# %%
df = pd.read_csv('Lowes_data.csv', na_values=['NA'])

# %%
df
# Out:
#                      Brand                                 Description  \
# 0               Northlight     1.83-ft 22-in Harvest Artificial Wreath
# 1                Glitzhome     2-ft 24-in Sunflowers Artificial Wreath
# 2            Worth Imports      1.75-ft 21-in Leaves Artificial Wreath
# 3    National Tree Company        2-ft 22-in Harvest Artificial Wreath
# 4    National Tree Company  1.83-ft 22-in Sunflowers Artificial Wreath
# ..                     ...                                         ...
# 141          Worth Imports      2.5-ft 30-in Berries Artificial Wreath
# 142          Worth Imports      1.8-ft 20-in Berries Artificial Wreath
# 143             Northlight      0.5-ft 28-in Harvest Artificial Wreath
# 144         Nearly Natural             6-ft Harvest Artificial Garland
# 145             Northlight      0.5-ft 26-in Harvest Artificial Wreath
#
#            ModelId  Price                                         ProductURL
# 0         34316662  49.98  https://www.lowes.com/pd/Northlight-1-83-ft-22...
# 1       2006300035  63.98  https://www.lowes.com/pd/Glitzhome-2-ft-24-in-...
# 2             9991  60.48  https://www.lowes.com/pd/Worth-Imports-1-75-ft...
# 3    RAHV-DA102W-1  44.88  https://www.lowes.com/pd/National-Tree-Company...
# 4    RAHV-W060630A  39.98  https://www.lowes.com/pd/National-Tree-Company...
# ..             ...    ...                                                ...
# 141           9984  79.48  https://www.lowes.com/pd/Worth-Imports-2-5-ft-...
# 142           7771  37.98  https://www.lowes.com/pd/Worth-Imports-20-in-B...
# 143       35762375  74.98  https://www.lowes.com/pd/Northlight-0-5-ft-28-...
# 144          W1236  74.98  https://www.lowes.com/pd/Nearly-Natural-6-ft-H...
# 145       35762346  73.98  https://www.lowes.com/pd/Northlight-0-5-ft-26-...
#
# [146 rows x 5 columns]

# %% [markdown]
# # No.of Wreaths per Brand

# %%
pd.DataFrame(df['Brand'].value_counts())
# Out:
#                        count
# Brand
# Nearly Natural            39
# Worth Imports             37
# Northlight                35
# National Tree Company     14
# Sullivans                  9
# Glitzhome                  4
# Gerson International       2
# Puleo International        2
# Fraser Hill Farm           1

# %% [markdown]
# # Price range for wreaths

# %%
df.groupby("Brand").agg({'Price': ['max', 'min']}).reset_index()
# Out:
#                    Brand   Price
#                              max     min
# 0       Fraser Hill Farm   40.16   40.16
# 1   Gerson International   53.98   45.00
# 2              Glitzhome   63.98   30.48
# 3  National Tree Company   95.64   37.35
# 4         Nearly Natural   90.77   31.95
# 5             Northlight   95.01   23.98
# 6    Puleo International  135.00  135.00
# 7              Sullivans   45.00   26.98
# 8          Worth Imports   94.98   18.97

# %% [markdown]
# # Histogram of product prices

# %%
import matplotlib.pyplot as plt

plt.hist(df['Price'], bins=20) 
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Product Prices')
plt.show()

# %% [markdown]
# # Most frequently occurring features and keywords from the product descriptions

# %%
from wordcloud import WordCloud

all_descriptions = " ".join(df['Description'].dropna())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_descriptions)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Feature Popularity Analysis - Word Cloud', fontsize=16)
plt.show()
